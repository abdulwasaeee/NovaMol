# %%
from PerformanceInsights import *
# Out:
# Using device: cuda

# %%
# CHEMBL4800 has only 18 compounds

# %%
# CHEMBL2094 has only 65 compounds

# %%
# CHEMBL246 has only 43 compounds

# %%
run_all_gnn(dataset='CHEMBL203')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL203 ---
# --- Downloading data for target CHEMBL203 from ChEMBL ---
# /mnt/c/Raja/my_project/forked/NovaMol/GNN_MODEL_TESTING/MULTI_TASK_GNN/PerformanceInsights.py:164: DtypeWarning: Columns (0,7,8,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f'data/{target_id}_raw_chembl.csv')
# Downloaded and cleaned 9739 unique, active compounds.
# Processed down to 9739 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL203_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 9739/9739 [00:04<00:00, 1962.23it/s]
# Data split: 6870 train, 1408 validation, 1461 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.9975 | MSE: 1.4073 | RMSE: 1.1863 | R2: 0.0248
# ...

# %%
run_all_gnn(dataset='CHEMBL240')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL240 ---
# --- Downloading data for target CHEMBL240 from ChEMBL ---
# Downloaded and cleaned 6434 unique, active compounds.
# Processed down to 6434 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL240_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 6434/6434 [00:03<00:00, 2124.66it/s]
# Data split: 4538 train, 930 validation, 966 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.6068 | MSE: 0.6608 | RMSE: 0.8129 | R2: 0.0001
# logp: MAE: 0.9953 | MSE: 2.2299 | RMSE: 1.4933 | R2: 0.0055
# molecular_weight: MAE: 69.0654 | MSE: 22005.3926 | RMSE: 148.3421 | R2: 0.0023
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.5964 | MSE: 0.6627 | RMSE: 0.8141 | R2: -0.0028
# ...

# %%
run_all_gnn(dataset='CHEMBL202')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL202 ---
# --- Downloading data for target CHEMBL202 from ChEMBL ---
# Downloaded and cleaned 777 unique, active compounds.
# Processed down to 777 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL202_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 777/777 [00:00<00:00, 2443.09it/s]
# Data split: 547 train, 113 validation, 117 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.7929 | MSE: 0.8902 | RMSE: 0.9435 | R2: 0.0001
# logp: MAE: 1.1059 | MSE: 1.9603 | RMSE: 1.4001 | R2: 0.0031
# molecular_weight: MAE: 65.6701 | MSE: 6785.9160 | RMSE: 82.3767 | R2: 0.0005
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.7871 | MSE: 0.8899 | RMSE: 0.9434 | R2: 0.0003
# ...

# %%
run_all_gnn(dataset='CHEMBL1978')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL1978 ---
# --- Downloading data for target CHEMBL1978 from ChEMBL ---
# Downloaded and cleaned 2402 unique, active compounds.
# Processed down to 2402 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL1978_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 2402/2402 [00:00<00:00, 2621.05it/s]
# Data split: 1694 train, 347 validation, 361 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.8808 | MSE: 1.1904 | RMSE: 1.0910 | R2: 0.0222
# logp: MAE: 1.0198 | MSE: 1.8706 | RMSE: 1.3677 | R2: 0.0347
# molecular_weight: MAE: 61.3856 | MSE: 8005.7065 | RMSE: 89.4746 | R2: 0.0521
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.8877 | MSE: 1.1557 | RMSE: 1.0750 | R2: 0.0507
# ...

# %%
run_all_gnn(dataset='CHEMBL226')
# Out:
# --- Starting NovaMol Pipeline for Target: CHEMBL226 ---
# --- Downloading data for target CHEMBL226 from ChEMBL ---
# Downloaded and cleaned 492 unique, active compounds.
# Processed down to 492 compounds with all required properties.
# Processed analysis results saved to data/CHEMBL226_processed_analysis.csv
#
# --- 1. Preparing Data for Multi-Task GNN ---
# Creating GNN graphs: 100%|██████████| 492/492 [00:00<00:00, 2052.24it/s]
# Data split: 346 train, 72 validation, 74 test.
#
# --- Running pipeline for MultiTaskGNN_v1 ---
#
# --- 2. Training Multi-Task Predictive GNN ---
#
# GNN Epoch 01 | Validation Metrics:
# pchembl_value: MAE: 0.8445 | MSE: 1.0710 | RMSE: 1.0349 | R2: -0.0004
# logp: MAE: 1.3172 | MSE: 3.1908 | RMSE: 1.7863 | R2: 0.0060
# molecular_weight: MAE: 74.1291 | MSE: 12908.2070 | RMSE: 113.6143 | R2: -0.0064
#
#
# GNN Epoch 02 | Validation Metrics:
# pchembl_value: MAE: 0.8709 | MSE: 1.1533 | RMSE: 1.0739 | R2: -0.0773
# ...
